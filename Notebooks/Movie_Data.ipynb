# %%
# Dependencies
import requests
from config import api_key
import pandas as pd
from pprint import pprint

# import file
file_df = ("C:/Users/miesb/OneDrive/Desktop/grab_popcorn/Data/movies_metadata.csv/movies_metadata.csv")

#read file
movie_df = pd.read_csv(file_df, low_memory=False)

#sample data
movie_df.head()
# Out:
#      imdb_id  adult                              belongs_to_collection  \
# 0  tt0114709  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1  tt0113497  FALSE                                                NaN
# 2  tt0113228  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3  tt0114885  FALSE                                                NaN
# 4  tt0113041  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...
#
#      budget      genres                              homepage     id  \
# 0  30000000   Animation  http://toystory.disney.com/toy-story    862
# 1  65000000   Adventure                                   NaN   8844
# 2         0     Romance                                   NaN  15602
# 3  16000000      Comedy                                   NaN  31357
# 4         0      Comedy                                   NaN  11862
#
#   original_language               original_title  \
# 0                en                    Toy Story
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                45449 non-null  object
#  1   adult                  45466 non-null  object
#  2   belongs_to_collection  4494 non-null   object
#  3   budget                 45466 non-null  object
#  4   genres                 43024 non-null  object
#  5   homepage               7782 non-null   object
#  6   id                     45466 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
print(movie_df['revenue'].head())
# Out:
# 0    373554033
# 1    262797249
# 2            0
# 3     81452156
# 4     76578911
# Name: revenue, dtype: int64

# %%
movie_df.drop(columns=['production_companies', 'production_countries'], inplace=True)

# %%
movie_df['popularity'] = pd.to_numeric(movie_df['popularity'], errors='coerce')

# %%
movie_df['id'] = pd.to_numeric(movie_df['id'], errors='coerce')

# %%
movie_df['tagline'] = movie_df['tagline'].dropna(inplace=True)

# %%
movie_df['adult'] = movie_df['adult'].astype(bool)

# %%
movie_df['video'] = movie_df['video'].astype(bool)

# %%
movie_df['release_date'] = pd.to_datetime(movie_df['release_date'], errors='coerce')

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                45449 non-null  object
#  1   adult                  45466 non-null  bool
#  2   belongs_to_collection  4494 non-null   object
#  3   genres                 43024 non-null  object
#  4   id                     45463 non-null  float64
#  5   original_language      45455 non-null  object
#  6   original_title         45466 non-null  object
#  7   overview               44512 non-null  object
#  8   popularity             45460 non-null  float64
#  9   release_date           45298 non-null  datetime64[ns]
#  10  revenue                45460 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  status                 45379 non-null  object
#  13  tagline                0 non-null      object
# ...

# %%
movie_df.to_csv('movie_data.csv', index=False)

# %%
movie_df.head()
# Out:
#      imdb_id  adult                              belongs_to_collection  \
# 0  tt0114709   True  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1  tt0113497   True                                                NaN
# 2  tt0113228   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3  tt0114885   True                                                NaN
# 4  tt0113041   True  {'id': 96871, 'name': 'Father of the Bride Col...
#
#        genres       id original_language               original_title  \
# 0   Animation    862.0                en                    Toy Story
# 1   Adventure   8844.0                en                      Jumanji
# 2     Romance  15602.0                en             Grumpier Old Men
# 3      Comedy  31357.0                en            Waiting to Exhale
# 4      Comedy  11862.0                en  Father of the Bride Part II
#
#                                             overview  popularity release_date  \
# ...
